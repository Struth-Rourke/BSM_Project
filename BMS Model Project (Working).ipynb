# %% [markdown]
# # Build Week 2 -- Modeling Project

# %% [markdown]
# ## Unzipping, Reading CSV, and Creating a DF via Concatenation

# %%
# import os
# import zipfile

# ## Unzipping each file in the filefolder and putting them in the 'unzipped' directory
# def gather_data(filefolder):
#     """ Produces List of Documents from a Directory
#     filefolder (str): a path of .zip files
#     returns list of strings"""
    
#     files = os.listdir(filefolder) 
#     for csv_zips in files: 
#         path = os.path.join(filefolder, csv_zips)
#         if  path[-3:] == 'zip':
#             with zipfile.ZipFile(path, 'r') as zip_ref:
#                 zip_ref.extractall('./SPX CBOE Data/unzipped')

                
# ## Calling the gather_data function (above)
# gather_data('./SPX CBOE Data')

# %%
# import pandas as pd

# ## Instantiating a new, empty list
# lst = []

# ## Reading in one CSV at a time, sampling 10%, and then appending the sample to 'lst'
# def readin_csv(filefolder):
#     """Reads in a list of csv documents from a directory 
#     filefoler (str): a path of .csv files returns list of 
#     strings"""
    
#     files = os.listdir(filefolder)
#     for csvs in files:
#         path = os.path.join(filefolder, csvs)
#         if  path[-3:] == 'csv':
#             temp_frame = pd.read_csv(path)
#             lst.append(temp_frame.sample(frac = 0.1))

            
# ## Calling the readin_csv function (above)
# readin_csv('./SPX CBOE Data/unzipped')

# ## Viewing the first couple of rows 'lst'
# lst[:5]

# %%
# ## Viewing all the available rows
# pd.set_option('display.max_columns', None)

# ## Creating a pandas dataframe by concatenating the list objects
# df = pd.concat(objs = lst, axis = 0)

# # CHECK:
# print(df.shape)
# df.head()

# %%
# df.to_csv('df_file')

# %%
# Ignore Warnings
import warnings
warnings.filterwarnings('ignore')


import pandas as pd
# Viewing all the columns
pd.set_option('display.max_columns', None)

# Reading in the csv
df = pd.read_csv('df_file', index_col = [0])

# CHECK:
df.head()
# Out:
#       underlying_symbol           quote_datetime  sequence_number  root  \
# 35324              ^SPX  2019-02-26 11:00:22.175        108071565   SPX
# 33006              ^SPX  2019-02-26 10:57:01.150        103929611   SPX
# 34887              ^SPX  2019-02-26 13:10:58.875        197160234  SPXW
# 22376              ^SPX  2019-02-26 10:00:46.050         46176372   SPX
# 2670               ^SPX  2019-02-26 06:33:35.900          2585428  SPXW
#
#        expiration  strike option_type  exchange_id  trade_size  trade_price  \
# 35324  2019-06-21  2600.0           C            5           1        230.2
# 33006  2019-04-18  2840.0           C            5           3         27.7
# 34887  2019-05-17  2835.0           C            5           5         45.6
# 22376  2019-03-15  2525.0           P            5           6          1.6
# 2670   2019-02-27  2775.0           P            5           1          5.5
#
#        trade_condition_id  canceled_trade_condition_id  best_bid  best_ask  \
# 35324                   0                            0     229.3    230.20
# 33006                  35                            0      27.5     27.90
# 34887                   0                            0      45.6     46.00
# 22376                   0                            0       1.6      1.65
# 2670                    0                            0       5.0      5.80
#
#        trade_iv  trade_delta  underlying_bid  underlying_ask  \
# 35324    0.1764       0.7835         2789.90         2790.73
# 33006    0.1114       0.3594         2791.56         2792.38
# 34887    0.1188       0.4180         2794.04         2794.75
# 22376    0.2474      -0.0276         2792.09         2793.30
# 2670     0.1596      -0.3083            0.00            0.00
#
#        number_of_exchanges  {exchange  bid_size    bid  ask_size  \
# 35324                    1        5.0      70.0  229.3       1.0
# 33006                    1        5.0     321.0   27.5      75.0
# 34887                    1        5.0      14.0   45.6      14.0
# 22376                    1        5.0      10.0    1.6     264.0
# 2670                     1        5.0      86.0    5.0      43.0
#
#        ask}[number_of_exchanges]
# 35324                     230.20
# 33006                      27.90
# 34887                      46.00
# 22376                       1.65
# 2670                        5.80

# %%
df = df.reset_index(drop = True)
df.head()
# Out:
#   underlying_symbol           quote_datetime  sequence_number  root  \
# 0              ^SPX  2019-02-26 11:00:22.175        108071565   SPX
# 1              ^SPX  2019-02-26 10:57:01.150        103929611   SPX
# 2              ^SPX  2019-02-26 13:10:58.875        197160234  SPXW
# 3              ^SPX  2019-02-26 10:00:46.050         46176372   SPX
# 4              ^SPX  2019-02-26 06:33:35.900          2585428  SPXW
#
#    expiration  strike option_type  exchange_id  trade_size  trade_price  \
# 0  2019-06-21  2600.0           C            5           1        230.2
# 1  2019-04-18  2840.0           C            5           3         27.7
# 2  2019-05-17  2835.0           C            5           5         45.6
# 3  2019-03-15  2525.0           P            5           6          1.6
# 4  2019-02-27  2775.0           P            5           1          5.5
#
#    trade_condition_id  canceled_trade_condition_id  best_bid  best_ask  \
# 0                   0                            0     229.3    230.20
# 1                  35                            0      27.5     27.90
# 2                   0                            0      45.6     46.00
# 3                   0                            0       1.6      1.65
# 4                   0                            0       5.0      5.80
#
#    trade_iv  trade_delta  underlying_bid  underlying_ask  number_of_exchanges  \
# 0    0.1764       0.7835         2789.90         2790.73                    1
# 1    0.1114       0.3594         2791.56         2792.38                    1
# 2    0.1188       0.4180         2794.04         2794.75                    1
# 3    0.2474      -0.0276         2792.09         2793.30                    1
# 4    0.1596      -0.3083            0.00            0.00                    1
#
#    {exchange  bid_size    bid  ask_size  ask}[number_of_exchanges]
# 0        5.0      70.0  229.3       1.0                     230.20
# 1        5.0     321.0   27.5      75.0                      27.90
# 2        5.0      14.0   45.6      14.0                      46.00
# 3        5.0      10.0    1.6     264.0                       1.65
# 4        5.0      86.0    5.0      43.0                       5.80

# %% [markdown]
# ## Data Cleaning, Analysis, Exploration, and Manipulation

# %%
## Viewing dtypes and info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2323610 entries, 0 to 2323609
# Data columns (total 24 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   underlying_symbol            object
#  1   quote_datetime               object
#  2   sequence_number              int64
#  3   root                         object
#  4   expiration                   object
#  5   strike                       float64
#  6   option_type                  object
#  7   exchange_id                  int64
#  8   trade_size                   int64
#  9   trade_price                  float64
#  10  trade_condition_id           int64
#  11  canceled_trade_condition_id  int64
#  12  best_bid                     float64
#  13  best_ask                     float64
#  14  trade_iv                     float64
#  15  trade_delta                  float64
#  16  underlying_bid               float64
#  17  underlying_ask               float64
#  18  number_of_exchanges          int64
#  19  {exchange                    float64
#  20  bid_size                     float64
#  21  bid                          float64
#  22  ask_size                     float64
#  23  ask}[number_of_exchanges]    float64
# dtypes: float64(13), int64(6), object(5)
# memory usage: 425.5+ MB

# %%
##### Creating a Wrangle Function to Clean Data and Create Features: #####
import numpy as np

def wrangle(X):
    """Wrangling a data sets and creating features 
    in the same way across copies."""
    
    ### Creating a df copy
    X = X.copy()
    
    ### Inferring the DateTime format to Dates / Time:
    X['quote_datetime'] = pd.to_datetime(X['quote_datetime'], infer_datetime_format = True)
    X['expiration'] = pd.to_datetime(X['expiration'], infer_datetime_format = True)
    
    ### DateTime Features:
    # Dates and Time
    X['datetime_year_month'] = (X['quote_datetime'].dt.to_period('M')).astype('str') # String for rate substitution later
    X['datetime_fulldate'] = X['quote_datetime'].dt.date
    X['datetime_time'] = X['quote_datetime'].dt.time
    # Time to Maturity (Days)
    X['time_to_maturity'] = X['expiration'] - X['quote_datetime']
    X['time_to_maturity'] = X['time_to_maturity'].astype('string')
    X['time_to_maturity'] = X['time_to_maturity'].str.split(' days').str[0]
    X['time_to_maturity'] = X['time_to_maturity'].astype('int')
    
    ### Column Adjustments:
    # Column Names Dictionary to make changes
    col_names = {
        'best_bid':'option_bid',
        'best_ask':'option_ask',
        'bid_size':'option_bid_size',
        'ask_size':'option_ask_size'
        
    }
    
    # Column Renaming
    X.rename(columns = col_names, inplace = True)
    
    # Dropping Unnecessary Columns
    col_drop = ['sequence_number', 'root', 'exchange_id', 'trade_condition_id',
                'canceled_trade_condition_id','number_of_exchanges','{exchange',
                'ask}[number_of_exchanges]', 'bid']
    
    X.drop(columns = col_drop, inplace = True)
    
    
    ### Feature Engineering:
    # option_bid_ask_spread -- Option Liquidty Proxy
    X['option_bid_ask_spread'] = X['option_ask'] - X['option_bid']
    
    # underlying_bid_ask_spread -- Underlying Liquidity Proxy
    X['underlying_bid_ask_spread'] =  X['underlying_ask'] - X['underlying_bid']
    
    # bid_ask_size_spread
    X['option_bid_ask_size_spread'] = X['option_ask_size'] - X['option_bid_size']
    
    # underlying_distance_from_strike
    X['distance_from_strike'] = X['underlying_ask'] - X['strike']
    
    # risk_free_rate -- Risk-Free Rate (10yr Treasury) Proxy for 'r' in BSM
    X['risk_free_rate'] = .0214
    
    # annualized vol 2019
    X['annualized_vol'] = .2888
    
    # Time to Expiration in decimal
    X['T'] = X['time_to_maturity'] / 365
    
    # erT
    X['erT'] = np.exp(-X['risk_free_rate'] * X['T'])
    
        
    ### Reordering Columns:
    # Column Ordering
    col_order = ['underlying_symbol',
                 'quote_datetime',
                 'datetime_fulldate',
                 'datetime_year_month',
                 'datetime_time',
                 'expiration',
                 'time_to_maturity',
                 'T',
                 'option_type',   
                 'strike',
                 'option_bid',
                 'option_ask',
                 'option_bid_size',
                 'option_ask_size',
                 'option_bid_ask_spread',
                 'option_bid_ask_size_spread',
                 'trade_size',
                 'trade_iv',
                 'trade_delta',
                 'annualized_vol',
                 'underlying_bid',
                 'underlying_ask',
                 'underlying_bid_ask_spread',
                 'distance_from_strike',
                 'risk_free_rate',
                 'erT',
                 'trade_price']
    # Changing Order
    X = X[col_order] 
    
    
    ### Cleaning
    # Returning only the 2019 year values
    X = X[X['datetime_year_month'] <= '2019-12']
    # Where TTM > 0
    X = X[X['time_to_maturity'] > 0]
    # Returning only rows where underlying ask != 0
    X = X[X['underlying_ask'] != 0]
    
    ### Resetting Index again for alignment purposes
    X = X.reset_index(drop = True)
        
    ### Return
    return X
    

    
## applying the wrangle function from above
dfx = wrangle(df)

# CHECK:
print(dfx.shape)
dfx.head()
# Out:
# (996664, 27)
#   underlying_symbol          quote_datetime datetime_fulldate  \
# 0              ^SPX 2019-02-26 11:00:22.175        2019-02-26
# 1              ^SPX 2019-02-26 10:57:01.150        2019-02-26
# 2              ^SPX 2019-02-26 13:10:58.875        2019-02-26
# 3              ^SPX 2019-02-26 10:00:46.050        2019-02-26
# 4              ^SPX 2019-02-26 10:53:02.525        2019-02-26
#
#   datetime_year_month    datetime_time expiration  time_to_maturity         T  \
# 0             2019-02  11:00:22.175000 2019-06-21               114  0.312329
# 1             2019-02  10:57:01.150000 2019-04-18                50  0.136986
# 2             2019-02  13:10:58.875000 2019-05-17                79  0.216438
# 3             2019-02  10:00:46.050000 2019-03-15                16  0.043836
# 4             2019-02  10:53:02.525000 2019-03-15                16  0.043836
#
#   option_type  strike  option_bid  option_ask  option_bid_size  \
# 0           C  2600.0       229.3      230.20             70.0
# 1           C  2840.0        27.5       27.90            321.0
# 2           C  2835.0        45.6       46.00             14.0
# 3           P  2525.0         1.6        1.65             10.0
# 4           P  2795.0        28.2       28.60            226.0
#
#    option_ask_size  option_bid_ask_spread  option_bid_ask_size_spread  \
# 0              1.0                   0.90                       -69.0
# 1             75.0                   0.40                      -246.0
# 2             14.0                   0.40                         0.0
# 3            264.0                   0.05                       254.0
# 4            187.0                   0.40                       -39.0
#
#    trade_size  trade_iv  trade_delta  annualized_vol  underlying_bid  \
# 0           1    0.1764       0.7835          0.2888         2789.90
# 1           3    0.1114       0.3594          0.2888         2791.56
# 2           5    0.1188       0.4180          0.2888         2794.04
# 3           6    0.2474      -0.0276          0.2888         2792.09
# 4          14    0.1107      -0.5006          0.2888         2793.48
#
#    underlying_ask  underlying_bid_ask_spread  distance_from_strike  \
# 0         2790.73                       0.83                190.73
# 1         2792.38                       0.82                -47.62
# 2         2794.75                       0.71                -40.25
# 3         2793.30                       1.21                268.30
# 4         2794.37                       0.89                 -0.63
#
#    risk_free_rate       erT  trade_price
# 0          0.0214  0.993338        230.2
# 1          0.0214  0.997073         27.7
# 2          0.0214  0.995379         45.6
# 3          0.0214  0.999062          1.6
# 4          0.0214  0.999062         27.0

# %% [markdown]
# ## BMS Model (for SPX Options)
#
# ### Inputs
#
#
# **S:** Current Stock Price
#
# **X:** Strike
#
# **T:** Time to Expiration (days / 365)
#
# **r:** Annualized Risk-Free Rate (10-year, FFR as proxies??)
#
#
# **sigma:** Annualized Standard Deviation of Stock Returns (Annualized IV?)
#
# \begin{align}
# \sigma
# \end{align}
#
#
# **d1**:
#
# \begin{equation}
# d_{1} = \frac{\ln(\frac{{S}} {X}) + (r + (\frac{{\sigma^2}} 2))T }{\sigma{\sqrt T}}
# \end{equation}
#
# **d2**:
#
# \begin{equation}
# d_{2} = d_{1} - \sigma\sqrt(T)
# \end{equation}
#
# **N(d1):** Gaussian Distribution of d1 (Call)
#
# **(erf = error function for partial differential equation)**
#
# \begin{equation}
# N(d_{1}) = \frac{1 + erf(\frac{d_{1}} {\sqrt2})} {2}
# \end{equation}
#
#
# **N(d2):** Probability Call Option lands ITM
#
# \begin{equation}
# N(d_{2}) = \frac{1 + erf(\frac{d_{2}} {\sqrt2})} {2}
# \end{equation}
#
# **iN(d1):** Gaussian Distribution of d1 (Put)
#
# \begin{equation}
# iN(d_{1}) = \frac{1 + erf(\frac{-d_{1}} {\sqrt2})} {2}
# \end{equation}
#
# **iN(d2):** Probability Put Option lands ITM
#
# \begin{equation}
# iN(d_{2}) = \frac{1 + erf(\frac{-d_{2}} {\sqrt2})} {2}
# \end{equation}
#
#
# ### Outputs
#
#
#
#
#
#
# **Call:**
#
# \begin{equation}
# C = S_{0}N(d_{1}) - Xe^{-r{T}} N(d_{2})
# \end{equation}
#
# **Put:**
#
# \begin{equation}
# P = X{e^{−rT}}N(−d_{2}) − S_{0}N(−d_{1})
# \end{equation}

# %%
from scipy.stats import norm
import numpy as np

# BSM Inputs Function
def bsm_inputs(dataf):
    
    Y = dataf.copy()
    
    S = Y['underlying_ask']
    K = Y['strike']
    r = Y['risk_free_rate']
    v = Y['annualized_vol']
    T = Y['T']
    
    D1 = ((np.log(S / K) + (r + (v ** 2 / 2))) * T) / (v * np.sqrt(T))
    Y['d1'] = D1
    
    D2 = D1 - (v * np.sqrt(T))
    Y['d2'] = D2
    
    Nd1 = norm.cdf(D1)
    Y['nd1'] = Nd1
    
    Nd2 = norm.cdf(D2)
    Y['nd2'] = Nd2
    
    return Y
 
# Calling the function on a df
dfy = bsm_inputs(dfx)

# CHECK:
print(dfy.shape)
dfy.head()
# Out:
# (996664, 31)
#   underlying_symbol          quote_datetime datetime_fulldate  \
# 0              ^SPX 2019-02-26 11:00:22.175        2019-02-26
# 1              ^SPX 2019-02-26 10:57:01.150        2019-02-26
# 2              ^SPX 2019-02-26 13:10:58.875        2019-02-26
# 3              ^SPX 2019-02-26 10:00:46.050        2019-02-26
# 4              ^SPX 2019-02-26 10:53:02.525        2019-02-26
#
#   datetime_year_month    datetime_time expiration  time_to_maturity         T  \
# 0             2019-02  11:00:22.175000 2019-06-21               114  0.312329
# 1             2019-02  10:57:01.150000 2019-04-18                50  0.136986
# 2             2019-02  13:10:58.875000 2019-05-17                79  0.216438
# 3             2019-02  10:00:46.050000 2019-03-15                16  0.043836
# 4             2019-02  10:53:02.525000 2019-03-15                16  0.043836
#
#   option_type  strike  option_bid  option_ask  option_bid_size  \
# 0           C  2600.0       229.3      230.20             70.0
# 1           C  2840.0        27.5       27.90            321.0
# 2           C  2835.0        45.6       46.00             14.0
# 3           P  2525.0         1.6        1.65             10.0
# 4           P  2795.0        28.2       28.60            226.0
#
#    option_ask_size  option_bid_ask_spread  option_bid_ask_size_spread  \
# 0              1.0                   0.90                       -69.0
# 1             75.0                   0.40                      -246.0
# 2             14.0                   0.40                         0.0
# 3            264.0                   0.05                       254.0
# 4            187.0                   0.40                       -39.0
#
#    trade_size  trade_iv  trade_delta  annualized_vol  underlying_bid  \
# 0           1    0.1764       0.7835          0.2888         2789.90
# 1           3    0.1114       0.3594          0.2888         2791.56
# 2           5    0.1188       0.4180          0.2888         2794.04
# 3           6    0.2474      -0.0276          0.2888         2792.09
# 4          14    0.1107      -0.5006          0.2888         2793.48
#
#    underlying_ask  underlying_bid_ask_spread  distance_from_strike  \
# 0         2790.73                       0.83                190.73
# 1         2792.38                       0.82                -47.62
# 2         2794.75                       0.71                -40.25
# 3         2793.30                       1.21                268.30
# 4         2794.37                       0.89                 -0.63
#
#    risk_free_rate       erT  trade_price        d1        d2       nd1  \
# 0          0.0214  0.993338        230.2  0.259102  0.097703  0.602222
# 1          0.0214  0.997073         27.7  0.059199 -0.047690  0.523603
# 2          0.0214  0.995379         45.6  0.078618 -0.055741  0.531332
# 3          0.0214  0.999062          1.6  0.118956  0.058490  0.547345
# 4          0.0214  0.999062         27.0  0.045584 -0.014882  0.518179
#
#         nd2
# 0  0.538916
# 1  0.480982
# 2  0.477774
# 3  0.523321
# 4  0.494063

# %% [markdown]
# # Modeling
#
# ### Train, Validate, Test Split

# %%
##### Train, Validation and Test Set Split: #####
from sklearn.model_selection import train_test_split

# Splitting original df into training and testing sets
train, test = train_test_split(dfy, train_size = .9, test_size = .1, random_state = 42)

# Splitting training df into training and validation sets
train, val = train_test_split(train, train_size = .8, test_size = .2, random_state = 42)

# CHECK:
print(train.shape, val.shape, test.shape)
train.head()
# Out:
# (717597, 31) (179400, 31) (99667, 31)
#        underlying_symbol          quote_datetime datetime_fulldate  \
# 672013              ^SPX 2019-04-15 11:59:21.400        2019-04-15
# 178438              ^SPX 2019-12-30 10:26:42.975        2019-12-30
# 415211              ^SPX 2019-08-09 09:40:32.900        2019-08-09
# 844498              ^SPX 2019-02-11 12:25:20.750        2019-02-11
# 666304              ^SPX 2019-06-11 13:55:55.075        2019-06-11
#
#        datetime_year_month    datetime_time expiration  time_to_maturity  \
# 672013             2019-04  11:59:21.400000 2019-04-17                 1
# 178438             2019-12  10:26:42.975000 2020-01-13                13
# 415211             2019-08  09:40:32.900000 2019-09-20                41
# 844498             2019-02  12:25:20.750000 2019-02-13                 1
# 666304             2019-06  13:55:55.075000 2019-06-17                 5
#
#                T option_type  strike  option_bid  option_ask  option_bid_size  \
# 672013  0.002740           P  2900.0        8.60         8.9             17.0
# 178438  0.035616           P  3000.0        2.55         2.7            460.0
# 415211  0.112329           P  2785.0       26.00        26.4            362.0
# 844498  0.002740           P  2700.0        7.70         8.0             36.0
# 666304  0.013699           C  2920.0        5.70         5.9             66.0
#
#         option_ask_size  option_bid_ask_spread  option_bid_ask_size_spread  \
# 672013             38.0                   0.30                        21.0
# 178438            299.0                   0.15                      -161.0
# 415211            442.0                   0.40                        80.0
# 844498             32.0                   0.30                        -4.0
# 666304            108.0                   0.20                        42.0
#
#         trade_size  trade_iv  trade_delta  annualized_vol  underlying_bid  \
# 672013          35    0.1007      -0.4879          0.2888         2899.35
# 178438           7    0.2134      -0.0458          0.2888         3216.94
# 415211           1    0.2039      -0.2187          0.2888         2931.36
# 844498          10    0.1522      -0.3617          0.2888         2710.69
# 666304           1    0.1165       0.2308          0.2888         2887.13
#
#         underlying_ask  underlying_bid_ask_spread  distance_from_strike  \
# 672013         2900.09                       0.74                  0.09
# 178438         3218.26                       1.32                218.26
# 415211         2933.70                       2.34                148.70
# 844498         2711.46                       0.77                 11.46
# 666304         2887.95                       0.82                -32.05
#
#         risk_free_rate       erT  trade_price        d1        d2       nd1  \
# 672013          0.0214  0.999941         8.72  0.011442 -0.003674  0.504565
# 178438          0.0214  0.999238         2.60  0.087128  0.032625  0.534715
# 415211          0.0214  0.997599        26.20  0.133597  0.036804  0.553139
# 844498          0.0214  0.999941         7.90  0.012204 -0.002912  0.504869
# 666304          0.0214  0.999707         5.80  0.021101 -0.012701  0.508417
#
#              nd2
# 672013  0.498534
# 178438  0.513013
# 415211  0.514679
# 844498  0.498838
# 666304  0.494933

# %% [markdown]
# ### Assigning Features and Target

# %%
import category_encoders as ce
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Target and Features
target = 'trade_price'
features = ['underlying_ask', 'option_type']
bsm_features = ['underlying_ask', 'nd1', 'strike', 'erT', 'nd2', 'option_type']

other_features = ['trade_iv', 'trade_delta', 'option_bid_ask_spread',
                  'underlying_bid_ask_spread', 'risk_free_rate', 'annualized_vol']

all_features = bsm_features + other_features


# y target vector
y_train = train[target]
y_val = val[target]
y_test = test[target]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-45b3e4149d8f> in <module>
# ----> 1 import category_encoders as ce
#       2 from sklearn.linear_model import LinearRegression
#       3 from sklearn.preprocessing import StandardScaler
#       4 from sklearn.metrics import mean_squared_error
#       5 from sklearn.metrics import r2_score
#
# ModuleNotFoundError: No module named 'category_encoders'

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.pipeline import make_pipeline

##### Linear Model 1 #####

# Features Assignment
X_train_bsm = train[bsm_features]
X_val_bsm = val[bsm_features]

# Linear Regression Pipeline
lr_pipeline = make_pipeline(
    ce.OrdinalEncoder(),
    StandardScaler(),
    LinearRegression()
)

# Fitting
lr_pipeline.fit(X_train_bsm, y_train)

# Prediction
y_pred_bsm = lr_pipeline.predict(X_val_bsm)


# Scoring
def scoring_func(pipelinemodel, features, Xval, yval, ypred_val):
    # Coefficients
    coefs = pipelinemodel.named_steps['linearregression'].coef_
    train_coefs = pd.Series(coefs, features)
    print('Model Coefficients:')
    print(train_coefs)
    print('\n')

    # Intercept
    intercept = pipelinemodel.named_steps['linearregression'].intercept_
    print('Intercept:', intercept)
    print('\n')

    # Mean Square Error (MSE) and Root Mean Square Error (RMSE)
    mse = mean_squared_error(yval, ypred_val)
    rmse = np.sqrt(mse)
    r2 = r2_score(yval, ypred_val)
    print('Mean Absolute Error (MSE):', mse)
    print('Root Mean Square Error (RMSE):', rmse)
    print('R^2:', r2)
    
    return 

scoring_func(lr_pipeline, bsm_features, X_train_bsm, y_val, y_pred_bsm)

# %%
##### Linear Model 2 #####

# Features 
X_train_other = train[other_features]
X_val_other = val[other_features]

# Linear Regression Pipeline
lr_pipeline2 = make_pipeline(
    ce.OrdinalEncoder(),
    StandardScaler(),
    LinearRegression()
)

# Fitting
lr_pipeline2.fit(X_train_other, y_train)

# Prediction
y_pred_other = lr_pipeline2.predict(X_val_other)

# Scoring
scoring_func(lr_pipeline2, other_features, X_train_other, y_val, y_pred_other)

# %%
##### Linear Model 3 #####

# Features 
X_train_all = train[all_features]
X_val_all = val[all_features]

# Linear Regression Pipeline
lr_pipeline3 = make_pipeline(
    ce.OrdinalEncoder(),
    StandardScaler(),
    LinearRegression()
)

# Fitting
lr_pipeline3.fit(X_train_all, y_train)

# Prediction
y_pred_all = lr_pipeline3.predict(X_val_all)

# Scoring
scoring_func(lr_pipeline3, all_features, X_train_all, y_val, y_pred_all)

# %% [markdown]
# ### Permutation Importances on Features

# %%
import eli5
from eli5.sklearn import PermutationImportance

# X Feature Matrices
X_train_bsm = train[bsm_features]
X_train_other = train[other_features]
X_train_all = train[all_features]

X_val_bsm = val[bsm_features]
X_val_other = val[other_features]
X_val_all = val[all_features]


# Linear Model Preprocessing Transformer
lr_transformer1 = make_pipeline(
    ce.OrdinalEncoder(),
    StandardScaler()
)

lr_transformer2 = make_pipeline(
    ce.OrdinalEncoder(),
    StandardScaler()
)

lr_transformer3 = make_pipeline(
    ce.OrdinalEncoder(),
    StandardScaler()
)

# Processing X Feature Matrices
X_train_bsm = lr_transformer1.fit_transform(X_train_bsm)
X_train_other = lr_transformer2.fit_transform(X_train_other)
X_train_all = lr_transformer3.fit_transform(X_train_all)

X_val_bsm = lr_transformer1.transform(X_val_bsm)
X_val_other = lr_transformer2.transform(X_val_other)
X_val_all = lr_transformer3.transform(X_val_all)


# Model Fitting Function
def modeling(model, Xtrain, Xval, ytrain, yval):
    """"""
    # Instantiating Model
    V = model
    # Fitted Model
    fitted_model = V.fit(Xtrain, ytrain)
    
    return fitted_model

bsm_fit = modeling(LinearRegression(), X_train_bsm, X_val_bsm, y_train, y_val)
print(bsm_fit)

other_fit = modeling(LinearRegression(), X_train_other, X_val_other, y_train, y_val)
print(other_fit)

all_fit = modeling(LinearRegression(), X_train_all, X_val_all, y_train, y_val)
print(all_fit)

# def eli_func(nonpipelinemodel, Xval, yval):
#     """Creates an eli5 weights graph."""
    
#     # Permutation
#     permutation = PermutationImportance(
#         nonpipelinemodel,
#         scoring = 'r2',
#         n_iter = 10,
#         random_state = 42
#     )
    
#     # Fitting Permutation
#     permutation.fit(Xval, yval)
    
#     # X Val Columns to a list for display
#     features_name = Xval.columns.tolist()
    
#     # eli5 graph
#     eli5_weights = eli5.show_weights(
#         permutation,
#         top = None,
#         feature_names = features_names
#     )
    
#     # Returning weights chart
#     return eli5_weights

# # Calling function and assigning the outout to a variable
# bsm_eli = eli_func(bsm_fit, X_val_bsm, y_val)
# other_eli = eli_func(other_fit, X_val_other, y_val)
# all_eli = eli_func(all_fit, X_val_all, y_val)

# # CHECK:
# bsm_eli

# %%
import eli5
from eli5.sklearn import PermutationImportance
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score


### Linear Model 1 ###


# X Features Matrix
X_train = train[bsm_features]
X_val = val[bsm_features]
X_test = test[bsm_features]

# X Features Matrix (Encoded and Scaled)
encoder = ce.OrdinalEncoder()
scaler = StandardScaler()

X_train = encoder.fit_transform(X_train)
X_val = encoder.transform(X_val)
X_test = encoder.transform(X_test)

X_train_sc = scaler.fit_transform(X_train)
X_val_sc = scaler.transform(X_val)
X_test_sc = scaler.transform(X_test)


# Creating a df for lm features and data ONLY
X_train_lm = pd.DataFrame(X_train_sc, columns = bsm_features)
X_val_lm = pd.DataFrame(X_val_sc, columns = bsm_features)
X_test_lm = pd.DataFrame(X_test_sc, columns = bsm_features)


# Instantiate Model
lr = LinearRegression()


# Fitted Model
lin_reg1 = lr.fit(X_train_lm, y_train)


# Prediction of X_val
y_pred_val = lin_reg1.predict(X_val_lm)

    
## Creating the permuter importance 
permutation = PermutationImportance(
    lin_reg1,
    scoring = 'r2',
    n_iter = 10,
    random_state = 42
)


## Fitting 
permutation.fit(X_val, y_val)
    
## eli5 Weightings Chart
# Adding feature names to a list
feature_names = X_val.columns.tolist()
    
# eli5 Chart
eli5_weights = eli5.show_weights(
    permutation,
    top = None,
    feature_names = feature_names
)
 
### Return    
eli5_weights

# %% [markdown]
# #### Other Features

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score


### Linear Model 2 ###


# X Features Matrix
X_train = train[other_features]
X_val = val[other_features]
X_test = test[other_features]

# X Features Matrix (Encoded and Scaled)
encoder = ce.OrdinalEncoder()
scaler = StandardScaler()


X_train = encoder.fit_transform(X_train)
X_val = encoder.transform(X_val)
X_test = encoder.transform(X_test)

X_train_sc = scaler.fit_transform(X_train)
X_val_sc = scaler.transform(X_val)
X_test_sc = scaler.transform(X_test)


# Creating a df for lm features and data ONLY
X_train_lm = pd.DataFrame(X_train_sc, columns = bsm_features)
X_val_lm = pd.DataFrame(X_val_sc, columns = bsm_features)
X_test_lm = pd.DataFrame(X_test_sc, columns = bsm_features)


# Instantiate Model
lr = LinearRegression()


# Fitted Model
lin_reg2 = lr.fit(X_train_lm, y_train)


# Prediction of X_val
y_pred_val = lin_reg2.predict(X_val_lm)


## Creating the permuter importance 
permutation = PermutationImportance(
    lin_reg2,
    scoring = 'r2',
    n_iter = 10,
    random_state = 42
)
    
## Fitting 
permutation.fit(X_val, y_val)
    
## eli5 Weightings Chart
# Adding feature names to a list
feature_names = X_val.columns.tolist()
    
# eli5 Chart
eli5_weights = eli5.show_weights(
    permutation,
    top = None,
    feature_names = feature_names
)
 
### Return    
eli5_weights

# %%
### Linear Model 3 ###


# X Features Matrix
X_train = train[all_features]
X_val = val[all_features]
X_test = test[all_features]

# X Features Matrix (Encoded)
encoder = ce.OrdinalEncoder()

X_train = encoder.fit_transform(X_train)
X_val = encoder.transform(X_val)
X_test = encoder.transform(X_test)

# Standard Scaler
scaler = StandardScaler()

X_train_sc = scaler.fit_transform(X_train)
X_val_sc = scaler.transform(X_val)
X_test_sc = scaler.transform(X_test)


# Creating a df for lm features and data ONLY
X_train_lm = pd.DataFrame(X_train_sc, columns = all_features)
X_val_lm = pd.DataFrame(X_val_sc, columns = all_features)
X_test_lm = pd.DataFrame(X_test_sc, columns = all_features)


# Instantiate Model
lr = LinearRegression()


# Fitted Model
lin_reg3 = lr.fit(X_train_lm, y_train)


# Prediction of X_val
y_pred_val = lin_reg3.predict(X_val_lm)


## Creating the permuter importance 
permutation = PermutationImportance(
    lin_reg3,
    scoring = 'r2',
    n_iter = 10,
    random_state = 42
)
    
## Fitting 
permutation.fit(X_val, y_val)
    
## eli5 Weightings Chart
# Adding feature names to a list
feature_names = X_val.columns.tolist()
    
# eli5 Chart
eli5_weights = eli5.show_weights(
    permutation,
    top = None,
    feature_names = feature_names
)
 
### Return    
eli5_weights

# %% [markdown]
# ### Random Forest Regressor
#
# #### Random Forest Model 1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor

# X Features Matrix
X_train = train[bsm_features]
X_val = val[bsm_features]
X_test = test[bsm_features]

# X Features Matrix (Encoded)
encoder = ce.OrdinalEncoder()

X_train = encoder.fit_transform(X_train)
X_val = encoder.transform(X_val)
X_test = encoder.transform(X_test)

## Instantiate Model
rf = RandomForestRegressor(n_jobs = -1)

# Fitted Model
rand_forest1 = rf.fit(X_train, y_train)
print('R^2:', rand_forest1.score(X_val, y_val))

# %%
### Graphing:

# Getting Features Importances
importances = pd.Series(rand_forest1.feature_importances_, X_train.columns)
        
# Plotting Importances
plt.figure(figsize = (10, 10))
plt.title('Feature Importances')
importances.sort_values(ascending = True).plot.barh(color = 'blue');

# %%
import eli5
from eli5.sklearn import PermutationImportance
    
## Creating the permuter importance 
permutation = PermutationImportance(
    rand_forest1,
    scoring = 'r2',
    n_iter = 10,
    random_state = 42
)
    
## Fitting 
permutation.fit(X_val, y_val)
    
## eli5 Weightings Chart
# Adding feature names to a list
feature_names = X_val.columns.tolist()
    
# eli5 Chart
eli5_weights = eli5.show_weights(
    permutation,
    top = None,
    feature_names = feature_names
)
 
### Return    
eli5_weights
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 7.4663
#
#                     &plusmn; 0.1236
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 option_type
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 5.6604
#
#                     &plusmn; 0.0645
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 nd2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.09%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 1.9848
#
#                     &plusmn; 0.1614
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 strike
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.72%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.5641
#
#                     &plusmn; 0.0116
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 erT
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.11%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4713
#
#                     &plusmn; 0.0101
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 nd1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0138
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 underlying_ask
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %% [markdown]
# #### Random Foest Model 2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor

# X Features Matrix
X_train = train[other_features]
X_val = val[other_features]
X_test = test[other_features]

# X Features Matrix (Encoded)
encoder = ce.OrdinalEncoder()

X_train = encoder.fit_transform(X_train)
X_val = encoder.transform(X_val)
X_test = encoder.transform(X_test)

## Instantiate Model
rf = RandomForestRegressor(n_jobs = -1)

# Fitted Model
rand_forest2 = rf.fit(X_train, y_train)
print('R^2:', rand_forest2.score(X_val, y_val))
# Out:
# R^2: 0.7094874789522962

# %%
### Graphing:

# Getting Features Importances
importances = pd.Series(rand_forest2.feature_importances_, X_train.columns)
        
# Plotting Importances
plt.figure(figsize = (10, 10))
plt.title('Feature Importances')
importances.sort_values(ascending = True).plot.barh(color = 'blue');

# %%
import eli5
from eli5.sklearn import PermutationImportance
    
## Creating the permuter importance 
permutation = PermutationImportance(
    rand_forest2,
    scoring = 'r2',
    n_iter = 10,
    random_state = 42
)
    
## Fitting 
permutation.fit(X_val, y_val)
    
## eli5 Weightings Chart
# Adding feature names to a list
feature_names = X_val.columns.tolist()
    
# eli5 Chart
eli5_weights = eli5.show_weights(
    permutation,
    top = None,
    feature_names = feature_names
)
 
### Return    
eli5_weights
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 1.2087
#
#                     &plusmn; 0.0204
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 trade_delta
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.32%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3082
#
#                     &plusmn; 0.0209
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 option_bid_ask_spread
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2131
#
#                     &plusmn; 0.0079
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 trade_iv
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.34%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0347
#
#                     &plusmn; 0.0217
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 underlying_bid_ask_spread
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 annualized_vol
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 risk_free_rate
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
# ## import certain packages
# from math import log, sqrt, pi, exp
# from scipy.stats import norm
# from datetime import datetime, date
# import numpy as np
# import pandas as pd
# from pandas import DataFrame


# ## define the call options price function
# def bs_call(S,K,T,r,sigma):
#     return S*norm.cdf(d1(S,K,T,r,sigma))-K*exp(-r*T)*norm.cdf(d2(S,K,T,r,sigma))


# ## define the put options price function
# def bs_put(S,K,T,r,sigma):
#     return K*exp(-r*T)-S+bs_call(S,K,T,r,sigma)


# ## define the Call_Greeks of an option
# def call_delta(S,K,T,r,sigma):
#     return norm.cdf(d1(S,K,T,r,sigma))
# def call_gamma(S,K,T,r,sigma):
#     return norm.pdf(d1(S,K,T,r,sigma))/(S*sigma*sqrt(T))
# def call_vega(S,K,T,r,sigma):
#     return 0.01*(S*norm.pdf(d1(S,K,T,r,sigma))*sqrt(T))
# def call_theta(S,K,T,r,sigma):
#     return 0.01*(-(S*norm.pdf(d1(S,K,T,r,sigma))*sigma)/(2*sqrt(T)) - r*K*exp(-r*T)*norm.cdf(d2(S,K,T,r,sigma)))
# def call_rho(S,K,T,r,sigma):
#     return 0.01*(K*T*exp(-r*T)*norm.cdf(d2(S,K,T,r,sigma)))

# ## define the Put_Greeks of an option
# def put_delta(S,K,T,r,sigma):
#     return -norm.cdf(-d1(S,K,T,r,sigma))
# def put_gamma(S,K,T,r,sigma):
#     return norm.pdf(d1(S,K,T,r,sigma))/(S*sigma*sqrt(T))
# def put_vega(S,K,T,r,sigma):
#     return 0.01*(S*norm.pdf(d1(S,K,T,r,sigma))*sqrt(T))
# def put_theta(S,K,T,r,sigma):
#     return 0.01*(-(S*norm.pdf(d1(S,K,T,r,sigma))*sigma)/(2*sqrt(T)) + r*K*exp(-r*T)*norm.cdf(-d2(S,K,T,r,sigma)))
# def put_rho(S,K,T,r,sigma):
#     return 0.01*(-K*T*exp(-r*T)*norm.cdf(-d2(S,K,T,r,sigma)))
